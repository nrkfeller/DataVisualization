# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def f(t):
    s1 = np.cos(2*np.pi*t)
    e1 = np.exp(-t)
    return np.multiply(s1,e1)

def scatterRandomPoints(n):
    plt.scatter(*np.random.randint(100, size = n * 2).reshape(2, n))

################
# First subplot
################
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
t3 = np.arange(0.0, 2.0, 0.01)

# Twice as tall as it is wide.
fig = plt.figure(figsize=plt.figaspect(2.))
#fig.suptitle('A tale of 2 subplots')
#ax = fig.add_subplot(2, 1, 1)
#l = ax.plot(t1, f(t1), 'bo',
#            t2, f(t2), 'k-', markerfacecolor='red')
#ax.grid(True)
#ax.set_ylabel('Damped oscillation')


#################
# Second subplot
#################
ax = fig.add_subplot(2, 1, 2, projection='3d')
X = np.arange(-20, 20, 0.25)
xlen = len(X)
Y = np.arange(-20, 20, 0.25)
ylen = len(Y)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

##X2 = np.random.choice(X[1::2],size=30)
#Y2 = np.random.choice(Y[1::2, 1::2],size=30)
#Z2 = np.random.choice(Z[1::2, 1::2],size=30)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, color='yellow',
        linewidth=0, antialiased=False)
scatteredpoints = ax.scatterRandomPoints(X[1::20, 1::20],
                                         Y[1::20, 1::20],
                                         Z[1::20, 1::20],
                                         linewidth=0, antialiased=False)



ax.set_zlim3d(-1, 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-971dd4c10aad> in <module>()
#      47 surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, color='yellow',
#      48         linewidth=0, antialiased=False)
# ---> 49 scatteredpoints = ax.scatterRandomPoints(X[1::20, 1::20],
#      50                                          Y[1::20, 1::20],
#      51                                          Z[1::20, 1::20],
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'scatterRandomPoints'
