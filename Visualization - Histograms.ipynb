# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from pandas import Series, DataFrame
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = 'https://en.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)
plt.hist(dataset1)
# Out:
# (array([  3.,   5.,   9.,  15.,  15.,  20.,  14.,   8.,   7.,   4.]),
#  array([-2.32572426, -1.8832295 , -1.44073475, -0.99823999, -0.55574524,
#         -0.11325049,  0.32924427,  0.77173902,  1.21423378,  1.65672853,
#          2.09922329]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([  5.,   3.,   5.,  12.,  16.,  16.,  10.,   5.,   4.,   4.]),
#  array([-2.05135781, -1.64917759, -1.24699736, -0.84481714, -0.44263691,
#         -0.04045669,  0.36172353,  0.76390376,  1.16608398,  1.5682642 ,
#          1.97044443]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.18648356,  0.12432237,  0.06216119,  0.12432237,  0.12432237,
#          0.18648356,  0.37296712,  0.37296712,  0.62161187,  0.37296712,
#          0.37296712,  0.62161187,  0.31080593,  0.31080593,  0.06216119,
#          0.24864475,  0.18648356,  0.06216119,  0.12432237,  0.12432237]),
#  array([-2.05135781, -1.8502677 , -1.64917759, -1.44808747, -1.24699736,
#         -1.04590725, -0.84481714, -0.64372703, -0.44263691, -0.2415468 ,
#         -0.04045669,  0.16063342,  0.36172353,  0.56281364,  0.76390376,
#          0.96499387,  1.16608398,  1.36717409,  1.5682642 ,  1.76935432,
#          1.97044443]),
#  <a list of 20 Patch objects>)

# %%
# using seaborn
data1 = randn(1000)
data2 = randn(1000)

# %%
# join plots
sns.jointplot(data1,data2)

# %%
# hexbins for more concise
sns.jointplot(data1,data2,kind='hex')
